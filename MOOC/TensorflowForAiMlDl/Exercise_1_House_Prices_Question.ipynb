# %% [markdown]
# <a href="https://colab.research.google.com/github/bhavintandel/machine-learning-portfolio/blob/master/MOOC/TensorflowForAiMlDl/Exercise_1_House_Prices_Question.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# In this exercise you'll try to build a neural network that predicts the price of a house according to a simple formula.
#
# So, imagine if house pricing was as easy as a house costs 50k + 50k per bedroom, so that a 1 bedroom house costs 100k, a 2 bedroom house costs 150k etc.
#
# How would you create a neural network that learns this relationship so that it would predict a 7 bedroom house as costing close to 400k etc.
#
# Hint: Your network might work better if you scale the house price down. You don't have to give the answer 400...it might be better to create something that predicts the number 4, and then your answer is in the 'hundreds of thousands' etc.

# %%
import tensorflow as tf
import numpy as np
from tensorflow import keras

# %%
model = keras.Sequential([keras.layers.Dense(1, input_shape=[1])])
#model.add(keras.layers.Activation('relu'))
model.compile(optimizer='sgd', loss='mean_squared_error')

# %%
xs = np.array([1,2,3,4,5,6], dtype=float)
ys = np.array([100, 150, 200, 250, 300, 350], dtype=float)

# %%
model.fit(xs, ys, epochs=500)
# Out:
# Epoch 1/500
# 6/6 [==============================] - 0s 37ms/sample - loss: 58197.1836
# Epoch 2/500
# 6/6 [==============================] - 0s 852us/sample - loss: 27069.7988
# Epoch 3/500
# 6/6 [==============================] - 0s 368us/sample - loss: 12662.1328
# Epoch 4/500
# 6/6 [==============================] - 0s 362us/sample - loss: 5992.8608
# Epoch 5/500
# 6/6 [==============================] - 0s 388us/sample - loss: 2905.1543
# Epoch 6/500
# 6/6 [==============================] - 0s 529us/sample - loss: 1475.1141
# Epoch 7/500
# 6/6 [==============================] - 0s 601us/sample - loss: 812.2982
# Epoch 8/500
# 6/6 [==============================] - 0s 584us/sample - loss: 504.5829
# Epoch 9/500
# 6/6 [==============================] - 0s 738us/sample - loss: 361.2259
# Epoch 10/500
# 6/6 [==============================] - 0s 912us/sample - loss: 293.9455
# Epoch 11/500
# 6/6 [==============================] - 0s 377us/sample - loss: 261.8825
# Epoch 12/500
# ...

# %%
print(model.predict([7.0]))
# Out:
# [[403.70563]]
